# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !git clone https://github.com/fizyr/keras-retinanet.git
# Out:
# Cloning into 'keras-retinanet'...
# remote: Enumerating objects: 6014, done.
# remote: Total 6014 (delta 0), reused 0 (delta 0), pack-reused 6014
# Receiving objects: 100% (6014/6014), 13.44 MiB | 7.59 MiB/s, done.
# Resolving deltas: 100% (4061/4061), done.

# %%
# %cd keras-retinanet/
# !pip install .
# Out:
# /kaggle/working/keras-retinanet
# Processing /kaggle/working/keras-retinanet
# Requirement already satisfied: keras in /opt/conda/lib/python3.7/site-packages (from keras-retinanet==0.5.1) (2.4.3)
# Collecting keras-resnet==0.2.0
#   Downloading keras-resnet-0.2.0.tar.gz (9.3 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from keras-retinanet==0.5.1) (1.14.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from keras-retinanet==0.5.1) (1.4.1)
# Requirement already satisfied: cython in /opt/conda/lib/python3.7/site-packages (from keras-retinanet==0.5.1) (0.29.21)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from keras-retinanet==0.5.1) (7.2.0)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (from keras-retinanet==0.5.1) (4.4.0.42)
# Collecting progressbar2
#   Downloading progressbar2-3.52.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras->keras-retinanet==0.5.1) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras->keras-retinanet==0.5.1) (1.18.5)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from keras->keras-retinanet==0.5.1) (5.3.1)
# Collecting python-utils>=2.3.0
#   Downloading python_utils-2.4.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: keras-retinanet, keras-resnet
#   Building wheel for keras-retinanet (setup.py) ... done
#   Created wheel for keras-retinanet: filename=keras_retinanet-0.5.1-cp37-cp37m-linux_x86_64.whl size=175140 sha256=559172a0ac52228db9af054d7ce8f9cfd173d71c43bb18e06d185d35fa1a23d6
#   Stored in directory: /root/.cache/pip/wheels/7f/ae/f4/f38a5a29bced2617252cb8aa726369b755c87eeef59fbba1d1
#   Building wheel for keras-resnet (setup.py) ... done
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20487 sha256=75dec9afcf3a5875d14c0ba8ee46d46b98e6ed1e01b7385398b16c9f88bc909a
#   Stored in directory: /root/.cache/pip/wheels/bd/ef/06/5d65f696360436c3a423020c4b7fd8c558c09ef264a0e6c575
# Successfully built keras-retinanet keras-resnet
# Installing collected packages: keras-resnet, python-utils, progressbar2, keras-retinanet
# Successfully installed keras-resnet-0.2.0 keras-retinanet-0.5.1 progressbar2-3.52.1 python-utils-2.4.0
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# cythoning keras_retinanet/utils/compute_overlap.pyx to keras_retinanet/utils/compute_overlap.c
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/keras-retinanet/keras_retinanet/utils/compute_overlap.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'keras_retinanet.utils.compute_overlap' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/keras_retinanet
# creating build/temp.linux-x86_64-3.7/keras_retinanet/utils
# gcc -pthread -B /opt/conda/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/conda/include/python3.7m -I/opt/conda/lib/python3.7/site-packages/numpy/core/include -c keras_retinanet/utils/compute_overlap.c -o build/temp.linux-x86_64-3.7/keras_retinanet/utils/compute_overlap.o
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1832:0,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from keras_retinanet/utils/compute_overlap.c:610:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/keras_retinanet
# creating build/lib.linux-x86_64-3.7/keras_retinanet/utils
# gcc -pthread -shared -B /opt/conda/compiler_compat -L/opt/conda/lib -Wl,-rpath=/opt/conda/lib -Wl,--no-as-needed -Wl,--sysroot=/ build/temp.linux-x86_64-3.7/keras_retinanet/utils/compute_overlap.o -o build/lib.linux-x86_64-3.7/keras_retinanet/utils/compute_overlap.cpython-37m-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.7/keras_retinanet/utils/compute_overlap.cpython-37m-x86_64-linux-gnu.so -> keras_retinanet/utils

# %%
import tensorflow as tf
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

# %%
from keras.models import Sequential, Model
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from keras.layers.advanced_activations import LeakyReLU
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.optimizers import SGD, Adam, RMSprop
from keras.layers.merge import concatenate
import matplotlib.pyplot as plt
import keras.backend as K
import tensorflow as tf
import imgaug as ia
from tqdm import tqdm
from imgaug import augmenters as iaa
import numpy as np
import pickle
import os, cv2
from preprocessing import parse_annotation, BatchGenerator
from utils import WeightReader, decode_netout, draw_boxes

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-caf7ca2f4de3> in <module>
#      14 import pickle
#      15 import os, cv2
# ---> 16 from preprocessing import parse_annotation, BatchGenerator
#      17 from utils import WeightReader, decode_netout, draw_boxes
#      18
#
# ImportError: cannot import name 'parse_annotation' from 'preprocessing' (/opt/conda/lib/python3.7/site-packages/preprocessing/__init__.py)

# %%
import pandas as pd
import numpy as np
import os
import cv2
from PIL import Image, ImageDraw
from ast import literal_eval
import matplotlib.pyplot as plt
import urllib
from tqdm.notebook import tqdm
import re

# %%
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from pandas.plotting import register_matplotlib_converters
from sklearn.model_selection import train_test_split
import urllib
import os
import csv
import cv2
import time
from PIL import Image

# %%
pwd
# Out:
# '/kaggle/working/keras-retinanet'

# %%
import xml.etree.cElementTree as et
import pandas as pd
import os

# %%
data_dir = '/kaggle/input/helmet/keras-yolo2-master/train_annot_folder'

# %%
a = os.listdir(data_dir)

# %%
a.sort()

# %%
a
# Out:
# ['applauding_001.xml',
#  'applauding_002.xml',
#  'applauding_003.xml',
#  'applauding_004.xml',
#  'applauding_005.xml',
#  'applauding_007.xml',
#  'applauding_008.xml',
#  'applauding_011.xml',
#  'applauding_012.xml',
#  'applauding_013.xml',
#  'applauding_014.xml',
#  'applauding_015.xml',
#  'applauding_016.xml',
#  'applauding_017.xml',
#  'applauding_018.xml',
#  'applauding_019.xml',
#  'applauding_020.xml',
#  'applauding_021.xml',
#  'applauding_022.xml',
#  'applauding_023.xml',
#  'applauding_024.xml',
#  'applauding_025.xml',
#  'applauding_026.xml',
#  'applauding_028.xml',
#  'applauding_029.xml',
#  'applauding_030.xml',
#  'applauding_032.xml',
#  'applauding_035.xml',
#  'applauding_036.xml',
#  'applauding_037.xml',
#  'applauding_038.xml',
#  'applauding_039.xml',
#  'applauding_040.xml',
#  'applauding_041.xml',
#  'applauding_042.xml',
#  'applauding_043.xml',
#  'applauding_044.xml',
#  'applauding_045.xml',
#  'applauding_046.xml',
#  'applauding_047.xml',
#  'applauding_048.xml',
#  'applauding_049.xml',
#  'applauding_050.xml',
#  'applauding_051.xml',
#  'applauding_052.xml',
#  'applauding_053.xml',
#  'applauding_054.xml',
#  'applauding_055.xml',
#  'applauding_056.xml',
#  'applauding_057.xml',
#  'applauding_058.xml',
#  'applauding_059.xml',
#  'applauding_060.xml',
#  'applauding_061.xml',
#  'applauding_062.xml',
#  'applauding_063.xml',
#  'applauding_064.xml',
#  'applauding_065.xml',
#  'applauding_066.xml',
#  'applauding_067.xml',
#  'applauding_068.xml',
#  'applauding_069.xml',
#  'applauding_070.xml',
#  'applauding_071.xml',
#  'applauding_072.xml',
#  'applauding_073.xml',
#  'applauding_074.xml',
#  'applauding_075.xml',
#  'applauding_076.xml',
#  'applauding_077.xml',
#  'applauding_078.xml',
#  'applauding_079.xml',
#  'applauding_080.xml',
#  'applauding_081.xml',
#  'applauding_082.xml',
#  'applauding_083.xml',
#  'applauding_084.xml',
#  'applauding_085.xml',
#  'applauding_086.xml',
#  'applauding_087.xml',
#  'applauding_088.xml',
#  'applauding_089.xml',
#  'applauding_090.xml',
#  'applauding_091.xml',
#  'applauding_093.xml',
#  'applauding_094.xml',
#  'applauding_095.xml',
#  'applauding_096.xml',
#  'applauding_097.xml',
#  'applauding_098.xml',
#  'applauding_099.xml',
#  'applauding_100.xml',
#  'applauding_101.xml',
#  'applauding_102.xml',
#  'applauding_103.xml',
#  'applauding_104.xml',
#  'applauding_105.xml',
#  'applauding_106.xml',
#  'applauding_107.xml',
#  'applauding_108.xml',
#  'applauding_109.xml',
#  'applauding_110.xml',
#  'applauding_111.xml',
#  'applauding_112.xml',
#  'applauding_113.xml',
#  'applauding_114.xml',
#  'applauding_115.xml',
#  'applauding_116.xml',
#  'applauding_117.xml',
#  'applauding_118.xml',
#  'applauding_120.xml',
#  'applauding_121.xml',
#  'applauding_122.xml',
#  'applauding_123.xml',
#  'applauding_124.xml',
#  'applauding_125.xml',
#  'applauding_126.xml',
#  'applauding_127.xml',
#  'applauding_128.xml',
#  'applauding_129.xml',
#  'applauding_130.xml',
#  'applauding_132.xml',
#  'applauding_133.xml',
#  'applauding_134.xml',
#  'applauding_135.xml',
#  'applauding_136.xml',
#  'applauding_138.xml',
#  'applauding_139.xml',
#  'applauding_142.xml',
#  'applauding_143.xml',
#  'applauding_144.xml',
#  'applauding_151.xml',
#  'applauding_152.xml',
#  'applauding_153.xml',
#  'applauding_154.xml',
#  'applauding_155.xml',
#  'applauding_156.xml',
#  'applauding_158.xml',
#  'applauding_159.xml',
#  'applauding_160.xml',
#  'applauding_162.xml',
#  'applauding_163.xml',
#  'applauding_169.xml',
#  'applauding_170.xml',
#  'applauding_171.xml',
#  'applauding_172.xml',
#  'applauding_173.xml',
#  'applauding_176.xml',
#  'applauding_177.xml',
#  'applauding_178.xml',
#  'applauding_179.xml',
#  'applauding_181.xml',
#  'person_without_helmet (1).xml',
#  'person_without_helmet (10).xml',
#  'person_without_helmet (100).xml',
#  'person_without_helmet (101).xml',
#  'person_without_helmet (102).xml',
#  'person_without_helmet (103).xml',
#  'person_without_helmet (104).xml',
#  'person_without_helmet (105).xml',
#  'person_without_helmet (106).xml',
#  'person_without_helmet (107).xml',
#  'person_without_helmet (108).xml',
#  'person_without_helmet (109).xml',
#  'person_without_helmet (11).xml',
#  'person_without_helmet (110).xml',
#  'person_without_helmet (111).xml',
#  'person_without_helmet (112).xml',
#  'person_without_helmet (113).xml',
#  'person_without_helmet (114).xml',
#  'person_without_helmet (115).xml',
#  'person_without_helmet (116).xml',
#  'person_without_helmet (117).xml',
#  'person_without_helmet (118).xml',
#  'person_without_helmet (119).xml',
#  'person_without_helmet (12).xml',
#  'person_without_helmet (120).xml',
#  'person_without_helmet (121).xml',
#  'person_without_helmet (122).xml',
#  'person_without_helmet (123).xml',
#  'person_without_helmet (124).xml',
#  'person_without_helmet (126).xml',
#  'person_without_helmet (127).xml',
#  'person_without_helmet (128).xml',
#  'person_without_helmet (129).xml',
#  'person_without_helmet (13).xml',
#  'person_without_helmet (130).xml',
#  'person_without_helmet (131).xml',
#  'person_without_helmet (132).xml',
#  'person_without_helmet (133).xml',
#  'person_without_helmet (134).xml',
#  'person_without_helmet (135).xml',
#  'person_without_helmet (136).xml',
#  'person_without_helmet (137).xml',
#  'person_without_helmet (138).xml',
#  'person_without_helmet (139).xml',
#  'person_without_helmet (14).xml',
#  'person_without_helmet (140).xml',
#  'person_without_helmet (141).xml',
#  'person_without_helmet (142).xml',
#  'person_without_helmet (143).xml',
#  'person_without_helmet (144).xml',
#  'person_without_helmet (145).xml',
#  'person_without_helmet (146).xml',
#  'person_without_helmet (147).xml',
#  'person_without_helmet (148).xml',
#  'person_without_helmet (149).xml',
#  'person_without_helmet (155).xml',
#  'person_without_helmet (156).xml',
#  'person_without_helmet (157).xml',
#  'person_without_helmet (158).xml',
#  'person_without_helmet (159).xml',
#  'person_without_helmet (160).xml',
#  'person_without_helmet (161).xml',
#  'person_without_helmet (162).xml',
#  'person_without_helmet (163).xml',
#  'person_without_helmet (164).xml',
#  'person_without_helmet (165).xml',
#  'person_without_helmet (166).xml',
#  'person_without_helmet (167).xml',
#  'person_without_helmet (168).xml',
#  'person_without_helmet (169).xml',
#  'person_without_helmet (170).xml',
#  'person_without_helmet (171).xml',
#  'person_without_helmet (172).xml',
#  'person_without_helmet (173).xml',
#  'person_without_helmet (174).xml',
#  'person_without_helmet (175).xml',
#  'person_without_helmet (176).xml',
#  'person_without_helmet (177).xml',
#  'person_without_helmet (180).xml',
#  'person_without_helmet (181).xml',
#  'person_without_helmet (182).xml',
#  'person_without_helmet (183).xml',
#  'person_without_helmet (184).xml',
#  'person_without_helmet (185).xml',
#  'person_without_helmet (186).xml',
#  'person_without_helmet (187).xml',
#  'person_without_helmet (188).xml',
#  'person_without_helmet (189).xml',
#  'person_without_helmet (190).xml',
#  'person_without_helmet (191).xml',
#  'person_without_helmet (192).xml',
#  'person_without_helmet (193).xml',
#  'person_without_helmet (194).xml',
#  'person_without_helmet (195).xml',
#  'person_without_helmet (196).xml',
#  'person_without_helmet (197).xml',
#  'person_without_helmet (198).xml',
#  'person_without_helmet (199).xml',
#  'person_without_helmet (200).xml',
#  'person_without_helmet (201).xml',
#  'person_without_helmet (202).xml',
#  'person_without_helmet (203).xml',
#  'person_without_helmet (204).xml',
#  'person_without_helmet (205).xml',
#  'person_without_helmet (206).xml',
#  'person_without_helmet (207).xml',
#  'person_without_helmet (208).xml',
#  'person_without_helmet (209).xml',
#  'person_without_helmet (210).xml',
#  'person_without_helmet (211).xml',
#  'person_without_helmet (212).xml',
#  'person_without_helmet (213).xml',
#  'person_without_helmet (214).xml',
#  'person_without_helmet (215).xml',
#  'person_without_helmet (216).xml',
#  'person_without_helmet (217).xml',
#  'person_without_helmet (218).xml',
#  'person_without_helmet (219).xml',
#  'person_without_helmet (220).xml',
#  'person_without_helmet (221).xml',
#  'person_without_helmet (222).xml',
#  'person_without_helmet (223).xml',
#  'person_without_helmet (224).xml',
#  'person_without_helmet (225).xml',
#  'person_without_helmet (226).xml',
#  'person_without_helmet (227).xml',
#  'person_without_helmet (228).xml',
#  'person_without_helmet (229).xml',
#  'person_without_helmet (230).xml',
#  'person_without_helmet (231).xml',
#  'person_without_helmet (232).xml',
#  'person_without_helmet (233).xml',
#  'person_without_helmet (234).xml',
#  'person_without_helmet (235).xml',
#  'person_without_helmet (236).xml',
#  'person_without_helmet (237).xml',
#  'person_without_helmet (238).xml',
#  'person_without_helmet (239).xml',
#  'person_without_helmet (240).xml',
#  'person_without_helmet (241).xml',
#  'person_without_helmet (242).xml',
#  'person_without_helmet (243).xml',
#  'person_without_helmet (244).xml',
#  'person_without_helmet (245).xml',
#  'person_without_helmet (246).xml',
#  'person_without_helmet (247).xml',
#  'person_without_helmet (248).xml',
#  'person_without_helmet (249).xml',
#  'person_without_helmet (250).xml',
#  'person_without_helmet (251).xml',
#  'person_without_helmet (252).xml',
#  'person_without_helmet (253).xml',
#  'person_without_helmet (254).xml',
#  'person_without_helmet (255).xml',
#  'person_without_helmet (256).xml',
#  'person_without_helmet (257).xml',
#  'person_without_helmet (258).xml',
#  'person_without_helmet (259).xml',
#  'person_without_helmet (260).xml',
#  'person_without_helmet (261).xml',
#  'person_without_helmet (262).xml',
#  'person_without_helmet (263).xml',
#  'person_without_helmet (264).xml',
#  'person_without_helmet (265).xml',
#  'person_without_helmet (266).xml',
#  'person_without_helmet (267).xml',
#  'person_without_helmet (268).xml',
#  'person_without_helmet (269).xml',
#  'person_without_helmet (270).xml',
#  'person_without_helmet (271).xml',
#  'person_without_helmet (272).xml',
#  'person_without_helmet (273).xml',
#  'person_without_helmet (274).xml',
#  'person_without_helmet (275).xml',
#  'person_without_helmet (276).xml',
#  'person_without_helmet (277).xml',
#  'person_without_helmet (278).xml',
#  'person_without_helmet (279).xml',
#  'person_without_helmet (280).xml',
#  'person_without_helmet (281).xml',
#  'person_without_helmet (282).xml',
#  'person_without_helmet (283).xml',
#  'person_without_helmet (284).xml',
#  'person_without_helmet (285).xml',
#  'person_without_helmet (286).xml',
#  'person_without_helmet (287).xml',
#  'person_without_helmet (288).xml',
#  'person_without_helmet (289).xml',
#  'person_without_helmet (290).xml',
#  'person_without_helmet (291).xml',
#  'person_without_helmet (292).xml',
#  'person_without_helmet (293).xml',
#  'person_without_helmet (294).xml',
#  'person_without_helmet (295).xml',
#  'person_without_helmet (296).xml',
#  'person_without_helmet (297).xml',
#  'person_without_helmet (3).xml',
#  'person_without_helmet (30).xml',
#  'person_without_helmet (31).xml',
#  'person_without_helmet (32).xml',
#  'person_without_helmet (33).xml',
#  'person_without_helmet (34).xml',
#  'person_without_helmet (35).xml',
#  'person_without_helmet (36).xml',
#  'person_without_helmet (37).xml',
#  'person_without_helmet (38).xml',
#  'person_without_helmet (39).xml',
#  'person_without_helmet (4).xml',
#  'person_without_helmet (40).xml',
#  'person_without_helmet (41).xml',
#  'person_without_helmet (42).xml',
#  'person_without_helmet (43).xml',
#  'person_without_helmet (44).xml',
#  'person_without_helmet (45).xml',
#  'person_without_helmet (46).xml',
#  'person_without_helmet (47).xml',
#  'person_without_helmet (48).xml',
#  'person_without_helmet (49).xml',
#  'person_without_helmet (5).xml',
#  'person_without_helmet (50).xml',
#  'person_without_helmet (51).xml',
#  'person_without_helmet (52).xml',
#  'person_without_helmet (53).xml',
#  'person_without_helmet (54).xml',
#  'person_without_helmet (55).xml',
#  'person_without_helmet (56).xml',
#  'person_without_helmet (57).xml',
#  'person_without_helmet (58).xml',
#  'person_without_helmet (59).xml',
#  'person_without_helmet (6).xml',
#  'person_without_helmet (60).xml',
#  'person_without_helmet (61).xml',
#  'person_without_helmet (62).xml',
#  'person_without_helmet (63).xml',
#  'person_without_helmet (64).xml',
#  'person_without_helmet (65).xml',
#  'person_without_helmet (66).xml',
#  'person_without_helmet (67).xml',
#  'person_without_helmet (68).xml',
#  'person_without_helmet (69).xml',
#  'person_without_helmet (7).xml',
#  'person_without_helmet (70).xml',
#  'person_without_helmet (71).xml',
#  'person_without_helmet (72).xml',
#  'person_without_helmet (73).xml',
#  'person_without_helmet (74).xml',
#  'person_without_helmet (75).xml',
#  'person_without_helmet (76).xml',
#  'person_without_helmet (77).xml',
#  'person_without_helmet (78).xml',
#  'person_without_helmet (79).xml',
#  'person_without_helmet (8).xml',
#  'person_without_helmet (80).xml',
#  'person_without_helmet (81).xml',
#  'person_without_helmet (82).xml',
#  'person_without_helmet (83).xml',
#  'person_without_helmet (84).xml',
#  'person_without_helmet (85).xml',
#  'person_without_helmet (86).xml',
#  'person_without_helmet (87).xml',
#  'person_without_helmet (88).xml',
#  'person_without_helmet (89).xml',
#  'person_without_helmet (9).xml',
#  'person_without_helmet (90).xml',
#  'person_without_helmet (91).xml',
#  'person_without_helmet (92).xml',
#  'person_without_helmet (93).xml',
#  'person_without_helmet (94).xml',
#  'person_without_helmet (96).xml',
#  'person_without_helmet (97).xml',
#  'person_without_helmet (98).xml',
#  'worker (1).xml',
#  'worker (10).xml',
#  'worker (100).xml',
#  'worker (101).xml',
#  'worker (102).xml',
#  'worker (103).xml',
#  'worker (104).xml',
#  'worker (105).xml',
#  'worker (106).xml',
#  'worker (107).xml',
#  'worker (108).xml',
#  'worker (109).xml',
#  'worker (11).xml',
#  'worker (110).xml',
#  'worker (111).xml',
#  'worker (112).xml',
#  'worker (113).xml',
#  'worker (114).xml',
#  'worker (115).xml',
#  'worker (116).xml',
#  'worker (117).xml',
#  'worker (118).xml',
#  'worker (119).xml',
#  'worker (12).xml',
#  'worker (120).xml',
#  'worker (121).xml',
#  'worker (122).xml',
#  'worker (123).xml',
#  'worker (124).xml',
#  'worker (125).xml',
#  'worker (126).xml',
#  'worker (127).xml',
#  'worker (128).xml',
#  'worker (129).xml',
#  'worker (13).xml',
#  'worker (130).xml',
#  'worker (131).xml',
#  'worker (132).xml',
#  'worker (133).xml',
#  'worker (134).xml',
#  'worker (135).xml',
#  'worker (136).xml',
#  'worker (137).xml',
#  'worker (138).xml',
#  'worker (139).xml',
#  'worker (14).xml',
#  'worker (140).xml',
#  'worker (141).xml',
#  'worker (142).xml',
#  'worker (143).xml',
#  'worker (144).xml',
#  'worker (145).xml',
#  'worker (146).xml',
#  'worker (147).xml',
#  'worker (148).xml',
#  'worker (149).xml',
#  'worker (15).xml',
#  'worker (150).xml',
#  'worker (151).xml',
#  'worker (152).xml',
#  'worker (153).xml',
#  'worker (154).xml',
#  'worker (155).xml',
#  'worker (156).xml',
#  'worker (158).xml',
#  'worker (159).xml',
#  'worker (16).xml',
#  'worker (160).xml',
#  'worker (161).xml',
#  'worker (162).xml',
#  'worker (163).xml',
#  'worker (164).xml',
#  'worker (165).xml',
#  'worker (166).xml',
#  'worker (167).xml',
#  'worker (168).xml',
#  'worker (169).xml',
#  'worker (17).xml',
#  'worker (170).xml',
#  'worker (171).xml',
#  'worker (172).xml',
#  'worker (173).xml',
#  'worker (175).xml',
#  'worker (176).xml',
#  'worker (177).xml',
#  'worker (178).xml',
#  'worker (179).xml',
#  'worker (18).xml',
#  'worker (180).xml',
#  'worker (181).xml',
#  'worker (182).xml',
#  'worker (183).xml',
#  'worker (184).xml',
#  'worker (185).xml',
#  'worker (186).xml',
#  'worker (187).xml',
#  'worker (188).xml',
#  'worker (189).xml',
#  'worker (19).xml',
#  'worker (190).xml',
#  'worker (191).xml',
#  'worker (192).xml',
#  'worker (193).xml',
#  'worker (194).xml',
#  'worker (195).xml',
#  'worker (196).xml',
#  'worker (197).xml',
#  'worker (198).xml',
#  'worker (199).xml',
#  'worker (2).xml',
#  'worker (20).xml',
#  'worker (200).xml',
#  'worker (201).xml',
#  'worker (203).xml',
#  'worker (204).xml',
#  'worker (205).xml',
#  'worker (206).xml',
#  'worker (207).xml',
#  'worker (208).xml',
#  'worker (209).xml',
#  'worker (21).xml',
#  'worker (211).xml',
#  'worker (212).xml',
#  'worker (213).xml',
#  'worker (214).xml',
#  'worker (215).xml',
#  'worker (216).xml',
#  'worker (217).xml',
#  'worker (218).xml',
#  'worker (219).xml',
#  'worker (220).xml',
#  'worker (221).xml',
#  'worker (222).xml',
#  'worker (223).xml',
#  'worker (224).xml',
#  'worker (225).xml',
#  'worker (226).xml',
#  'worker (227).xml',
#  'worker (228).xml',
#  'worker (229).xml',
#  'worker (23).xml',
#  'worker (230).xml',
#  'worker (231).xml',
#  'worker (232).xml',
#  'worker (233).xml',
#  'worker (234).xml',
#  'worker (235).xml',
#  'worker (236).xml',
#  'worker (237).xml',
#  'worker (238).xml',
#  'worker (239).xml',
#  'worker (24).xml',
#  'worker (240).xml',
#  'worker (241).xml',
#  'worker (242).xml',
#  'worker (243).xml',
#  'worker (244).xml',
#  'worker (245).xml',
#  'worker (247).xml',
#  'worker (248).xml',
#  'worker (249).xml',
#  'worker (25).xml',
#  'worker (250).xml',
#  'worker (251).xml',
#  'worker (252).xml',
#  'worker (253).xml',
#  'worker (254).xml',
#  'worker (255).xml',
#  'worker (256).xml',
#  'worker (257).xml',
#  'worker (258).xml',
#  'worker (259).xml',
#  'worker (26).xml',
#  'worker (260).xml',
#  'worker (261).xml',
#  'worker (262).xml',
#  'worker (263).xml',
#  'worker (264).xml',
#  'worker (265).xml',
#  'worker (266).xml',
#  'worker (267).xml',
#  'worker (268).xml',
#  'worker (269).xml',
#  'worker (27).xml',
#  'worker (270).xml',
#  'worker (271).xml',
#  'worker (272).xml',
#  'worker (273).xml',
#  'worker (275).xml',
#  'worker (276).xml',
#  'worker (278).xml',
#  'worker (279).xml',
#  'worker (28).xml',
#  'worker (280).xml',
#  'worker (281).xml',
#  'worker (282).xml',
#  'worker (283).xml',
#  'worker (284).xml',
#  'worker (285).xml',
#  'worker (289).xml',
#  'worker (29).xml',
#  'worker (290).xml',
#  'worker (291).xml',
#  'worker (293).xml',
#  'worker (295).xml',
#  'worker (296).xml',
#  'worker (298).xml',
#  'worker (299).xml',
#  'worker (3).xml',
#  'worker (30).xml',
#  'worker (300).xml',
#  'worker (301).xml',
#  'worker (302).xml',
#  'worker (304).xml',
#  'worker (305).xml',
#  'worker (306).xml',
#  'worker (307).xml',
#  'worker (308).xml',
#  'worker (309).xml',
#  'worker (310).xml',
#  'worker (312).xml',
#  'worker (313).xml',
#  'worker (314).xml',
#  'worker (315).xml',
#  'worker (316).xml',
#  'worker (317).xml',
#  'worker (318).xml',
#  'worker (319).xml',
#  'worker (32).xml',
#  'worker (320).xml',
#  'worker (321).xml',
#  'worker (322).xml',
#  'worker (323).xml',
#  'worker (324).xml',
#  'worker (327).xml',
#  'worker (328).xml',
#  'worker (33).xml',
#  'worker (330).xml',
#  'worker (331).xml',
#  'worker (332).xml',
#  'worker (333).xml',
#  'worker (334).xml',
#  'worker (335).xml',
#  'worker (337).xml',
#  'worker (338).xml',
#  'worker (339).xml',
#  'worker (34).xml',
#  'worker (340).xml',
#  'worker (341).xml',
#  'worker (345).xml',
#  'worker (346).xml',
#  'worker (348).xml',
#  'worker (349).xml',
#  'worker (35).xml',
#  'worker (350).xml',
#  'worker (351).xml',
#  'worker (353).xml',
#  'worker (354).xml',
#  'worker (355).xml',
#  'worker (357).xml',
#  'worker (359).xml',
#  'worker (36).xml',
#  'worker (361).xml',
#  'worker (362).xml',
#  'worker (363).xml',
#  'worker (364).xml',
#  'worker (365).xml',
#  'worker (366).xml',
#  'worker (368).xml',
#  'worker (369).xml',
#  'worker (37).xml',
#  'worker (371).xml',
#  'worker (372).xml',
#  'worker (373).xml',
#  'worker (374).xml',
#  'worker (375).xml',
#  'worker (376).xml',
#  'worker (377).xml',
#  'worker (378).xml',
#  'worker (379).xml',
#  'worker (38).xml',
#  'worker (380).xml',
#  'worker (381).xml',
#  'worker (382).xml',
#  'worker (383).xml',
#  'worker (384).xml',
#  'worker (385).xml',
#  'worker (386).xml',
#  'worker (387).xml',
#  'worker (388).xml',
#  'worker (389).xml',
#  'worker (39).xml',
#  'worker (390).xml',
#  'worker (391).xml',
#  'worker (392).xml',
#  'worker (393).xml',
#  'worker (394).xml',
#  'worker (395).xml',
#  'worker (396).xml',
#  'worker (397).xml',
#  'worker (398).xml',
#  'worker (399).xml',
#  'worker (4).xml',
#  'worker (40).xml',
#  'worker (400).xml',
#  'worker (401).xml',
#  'worker (402).xml',
#  'worker (403).xml',
#  'worker (404).xml',
#  'worker (405).xml',
#  'worker (406).xml',
#  'worker (407).xml',
#  'worker (408).xml',
#  'worker (409).xml',
#  'worker (41).xml',
#  'worker (410).xml',
#  'worker (411).xml',
#  'worker (412).xml',
#  'worker (413).xml',
#  'worker (414).xml',
#  'worker (415).xml',
#  'worker (416).xml',
#  'worker (417).xml',
#  'worker (418).xml',
#  'worker (419).xml',
#  'worker (42).xml',
#  'worker (420).xml',
#  'worker (421).xml',
#  'worker (422).xml',
#  'worker (423).xml',
#  'worker (424).xml',
#  'worker (425).xml',
#  'worker (426).xml',
#  'worker (427).xml',
#  'worker (428).xml',
#  'worker (429).xml',
#  'worker (43).xml',
#  'worker (430).xml',
#  'worker (431).xml',
#  'worker (432).xml',
#  'worker (433).xml',
#  'worker (434).xml',
#  'worker (435).xml',
#  'worker (436).xml',
#  'worker (437).xml',
#  'worker (438).xml',
#  'worker (439).xml',
#  'worker (44).xml',
#  'worker (440).xml',
#  'worker (441).xml',
#  'worker (442).xml',
#  'worker (443).xml',
#  'worker (444).xml',
#  'worker (445).xml',
#  'worker (446).xml',
#  'worker (447).xml',
#  'worker (448).xml',
#  'worker (449).xml',
#  'worker (45).xml',
#  'worker (450).xml',
#  'worker (451).xml',
#  'worker (452).xml',
#  'worker (453).xml',
#  'worker (454).xml',
#  'worker (455).xml',
#  'worker (456).xml',
#  'worker (457).xml',
#  'worker (458).xml',
#  'worker (459).xml',
#  'worker (46).xml',
#  'worker (460).xml',
#  'worker (461).xml',
#  'worker (462).xml',
#  'worker (463).xml',
#  'worker (464).xml',
#  'worker (465).xml',
#  'worker (466).xml',
#  'worker (467).xml',
#  'worker (468).xml',
#  'worker (469).xml',
#  'worker (47).xml',
#  'worker (470).xml',
#  'worker (471).xml',
#  'worker (472).xml',
#  'worker (473).xml',
#  'worker (474).xml',
#  'worker (475).xml',
#  'worker (476).xml',
#  'worker (477).xml',
#  'worker (478).xml',
#  'worker (479).xml',
#  'worker (48).xml',
#  'worker (480).xml',
#  'worker (481).xml',
#  'worker (482).xml',
#  'worker (483).xml',
#  'worker (484).xml',
#  'worker (485).xml',
#  'worker (486).xml',
#  'worker (487).xml',
#  'worker (488).xml',
#  'worker (489).xml',
#  'worker (49).xml',
#  'worker (490).xml',
#  'worker (491).xml',
#  'worker (492).xml',
#  'worker (493).xml',
#  'worker (494).xml',
#  'worker (495).xml',
#  'worker (496).xml',
#  'worker (497).xml',
#  'worker (498).xml',
#  'worker (499).xml',
#  'worker (5).xml',
#  'worker (50).xml',
#  'worker (500).xml',
#  'worker (501).xml',
#  'worker (502).xml',
#  'worker (503).xml',
#  'worker (504).xml',
#  'worker (505).xml',
#  'worker (506).xml',
#  'worker (507).xml',
#  'worker (508).xml',
#  'worker (509).xml',
#  'worker (51).xml',
#  'worker (510).xml',
#  'worker (511).xml',
#  'worker (512).xml',
#  'worker (513).xml',
#  'worker (514).xml',
#  'worker (515).xml',
#  'worker (516).xml',
#  'worker (517).xml',
#  'worker (518).xml',
#  'worker (519).xml',
#  'worker (52).xml',
#  'worker (520).xml',
#  'worker (521).xml',
#  'worker (522).xml',
#  'worker (523).xml',
#  'worker (524).xml',
#  'worker (525).xml',
#  'worker (526).xml',
#  'worker (527).xml',
#  'worker (528).xml',
#  'worker (529).xml',
#  'worker (53).xml',
#  'worker (530).xml',
#  'worker (532).xml',
#  'worker (533).xml',
#  'worker (534).xml',
#  'worker (535).xml',
#  'worker (536).xml',
#  'worker (537).xml',
#  'worker (538).xml',
#  'worker (539).xml',
#  'worker (54).xml',
#  'worker (540).xml',
#  'worker (541).xml',
#  'worker (542).xml',
#  'worker (543).xml',
#  'worker (544).xml',
#  'worker (547).xml',
#  'worker (548).xml',
#  'worker (549).xml',
#  'worker (55).xml',
#  'worker (550).xml',
#  'worker (551).xml',
#  'worker (552).xml',
#  'worker (553).xml',
#  'worker (554).xml',
#  'worker (555).xml',
#  'worker (556).xml',
#  'worker (557).xml',
#  'worker (558).xml',
#  'worker (559).xml',
#  'worker (56).xml',
#  'worker (560).xml',
#  'worker (561).xml',
#  'worker (562).xml',
#  'worker (563).xml',
#  'worker (564).xml',
#  'worker (565).xml',
#  'worker (566).xml',
#  'worker (567).xml',
#  'worker (568).xml',
#  'worker (569).xml',
#  'worker (57).xml',
#  'worker (570).xml',
#  'worker (571).xml',
#  'worker (572).xml',
#  'worker (573).xml',
#  'worker (574).xml',
#  'worker (575).xml',
#  'worker (576).xml',
#  'worker (577).xml',
#  'worker (578).xml',
#  'worker (579).xml',
#  'worker (58).xml',
#  'worker (580).xml',
#  'worker (581).xml',
#  'worker (582).xml',
#  'worker (583).xml',
#  'worker (584).xml',
#  'worker (585).xml',
#  'worker (586).xml',
#  'worker (587).xml',
#  'worker (588).xml',
#  'worker (589).xml',
#  'worker (59).xml',
#  'worker (590).xml',
#  'worker (591).xml',
#  'worker (592).xml',
#  'worker (593).xml',
#  'worker (594).xml',
#  'worker (595).xml',
#  'worker (596).xml',
#  'worker (597).xml',
#  'worker (598).xml',
#  'worker (599).xml',
#  'worker (6).xml',
#  'worker (60).xml',
#  'worker (600).xml',
#  'worker (601).xml',
#  'worker (602).xml',
#  'worker (603).xml',
#  'worker (604).xml',
#  'worker (605).xml',
#  'worker (606).xml',
#  'worker (607).xml',
#  'worker (608).xml',
#  'worker (609).xml',
#  'worker (61).xml',
#  'worker (610).xml',
#  'worker (611).xml',
#  'worker (612).xml',
#  'worker (613).xml',
#  'worker (614).xml',
#  'worker (615).xml',
#  'worker (616).xml',
#  'worker (617).xml',
#  'worker (618).xml',
#  'worker (619).xml',
#  'worker (62).xml',
#  'worker (620).xml',
#  'worker (621).xml',
#  'worker (622).xml',
#  'worker (623).xml',
#  'worker (624).xml',
#  'worker (625).xml',
#  'worker (626).xml',
#  'worker (627).xml',
#  'worker (628).xml',
#  'worker (629).xml',
#  'worker (63).xml',
#  'worker (630).xml',
#  'worker (631).xml',
#  'worker (632).xml',
#  'worker (633).xml',
#  'worker (634).xml',
#  'worker (635).xml',
#  'worker (636).xml',
#  'worker (637).xml',
#  'worker (638).xml',
#  'worker (639).xml',
#  'worker (64).xml',
#  'worker (640).xml',
#  'worker (641).xml',
#  'worker (642).xml',
#  'worker (643).xml',
#  'worker (644).xml',
#  'worker (645).xml',
#  'worker (646).xml',
#  'worker (647).xml',
#  'worker (648).xml',
#  'worker (649).xml',
#  ...]

# %%
xmin=[]
ymin=[]
xmax=[]
ymax=[]

# %%
for i in a:
    tree=et.parse(data_dir+ '/' + i)
    root=tree.getroot()
    for x in root.iter('bndbox'):
        root1=et.Element('root')
        root1=x
    for w in root1.iter('xmin'):
        xmin.append(w.text) 
    for x in root1.iter('ymin'):
        ymin.append(x.text)
    for y in root1.iter('xmax'):
        xmax.append(y.text)
    for z in root1.iter('ymax'):
        ymax.append(z.text)

# %%
b = os.listdir('/kaggle/input/helmet/keras-yolo2-master/train_image_folder')

# %%
b.sort()

# %%
b
# Out:
# ['applauding_001.jpg',
#  'applauding_002.jpg',
#  'applauding_003.jpg',
#  'applauding_004.jpg',
#  'applauding_005.jpg',
#  'applauding_007.jpg',
#  'applauding_008.jpg',
#  'applauding_011.jpg',
#  'applauding_012.jpg',
#  'applauding_013.jpg',
#  'applauding_014.jpg',
#  'applauding_015.jpg',
#  'applauding_016.jpg',
#  'applauding_017.jpg',
#  'applauding_018.jpg',
#  'applauding_019.jpg',
#  'applauding_020.jpg',
#  'applauding_021.jpg',
#  'applauding_022.jpg',
#  'applauding_023.jpg',
#  'applauding_024.jpg',
#  'applauding_025.jpg',
#  'applauding_026.jpg',
#  'applauding_028.jpg',
#  'applauding_029.jpg',
#  'applauding_030.jpg',
#  'applauding_032.jpg',
#  'applauding_035.jpg',
#  'applauding_036.jpg',
#  'applauding_037.jpg',
#  'applauding_038.jpg',
#  'applauding_039.jpg',
#  'applauding_040.jpg',
#  'applauding_041.jpg',
#  'applauding_042.jpg',
#  'applauding_043.jpg',
#  'applauding_044.jpg',
#  'applauding_045.jpg',
#  'applauding_046.jpg',
#  'applauding_047.jpg',
#  'applauding_048.jpg',
#  'applauding_049.jpg',
#  'applauding_050.jpg',
#  'applauding_051.jpg',
#  'applauding_052.jpg',
#  'applauding_053.jpg',
#  'applauding_054.jpg',
#  'applauding_055.jpg',
#  'applauding_056.jpg',
#  'applauding_057.jpg',
#  'applauding_058.jpg',
#  'applauding_059.jpg',
#  'applauding_060.jpg',
#  'applauding_061.jpg',
#  'applauding_062.jpg',
#  'applauding_063.jpg',
#  'applauding_064.jpg',
#  'applauding_065.jpg',
#  'applauding_066.jpg',
#  'applauding_067.jpg',
#  'applauding_068.jpg',
#  'applauding_069.jpg',
#  'applauding_070.jpg',
#  'applauding_071.jpg',
#  'applauding_072.jpg',
#  'applauding_073.jpg',
#  'applauding_074.jpg',
#  'applauding_075.jpg',
#  'applauding_076.jpg',
#  'applauding_077.jpg',
#  'applauding_078.jpg',
#  'applauding_079.jpg',
#  'applauding_080.jpg',
#  'applauding_081.jpg',
#  'applauding_082.jpg',
#  'applauding_083.jpg',
#  'applauding_084.jpg',
#  'applauding_085.jpg',
#  'applauding_086.jpg',
#  'applauding_087.jpg',
#  'applauding_088.jpg',
#  'applauding_089.jpg',
#  'applauding_090.jpg',
#  'applauding_091.jpg',
#  'applauding_093.jpg',
#  'applauding_094.jpg',
#  'applauding_095.jpg',
#  'applauding_096.jpg',
#  'applauding_097.jpg',
#  'applauding_098.jpg',
#  'applauding_099.jpg',
#  'applauding_100.jpg',
#  'applauding_101.jpg',
#  'applauding_102.jpg',
#  'applauding_103.jpg',
#  'applauding_104.jpg',
#  'applauding_105.jpg',
#  'applauding_106.jpg',
#  'applauding_107.jpg',
#  'applauding_108.jpg',
#  'applauding_109.jpg',
#  'applauding_110.jpg',
#  'applauding_111.jpg',
#  'applauding_112.jpg',
#  'applauding_113.jpg',
#  'applauding_114.jpg',
#  'applauding_115.jpg',
#  'applauding_116.jpg',
#  'applauding_117.jpg',
#  'applauding_118.jpg',
#  'applauding_120.jpg',
#  'applauding_121.jpg',
#  'applauding_122.jpg',
#  'applauding_123.jpg',
#  'applauding_124.jpg',
#  'applauding_125.jpg',
#  'applauding_126.jpg',
#  'applauding_127.jpg',
#  'applauding_128.jpg',
#  'applauding_129.jpg',
#  'applauding_130.jpg',
#  'applauding_132.jpg',
#  'applauding_133.jpg',
#  'applauding_134.jpg',
#  'applauding_135.jpg',
#  'applauding_136.jpg',
#  'applauding_138.jpg',
#  'applauding_139.jpg',
#  'applauding_142.jpg',
#  'applauding_143.jpg',
#  'applauding_144.jpg',
#  'applauding_151.jpg',
#  'applauding_152.jpg',
#  'applauding_153.jpg',
#  'applauding_154.jpg',
#  'applauding_155.jpg',
#  'applauding_156.jpg',
#  'applauding_158.jpg',
#  'applauding_159.jpg',
#  'applauding_160.jpg',
#  'applauding_162.jpg',
#  'applauding_163.jpg',
#  'applauding_169.jpg',
#  'applauding_170.jpg',
#  'applauding_171.jpg',
#  'applauding_172.jpg',
#  'applauding_173.jpg',
#  'applauding_176.jpg',
#  'applauding_177.jpg',
#  'applauding_178.jpg',
#  'applauding_179.jpg',
#  'applauding_181.jpg',
#  'person_without_helmet (1).jpg',
#  'person_without_helmet (10).jpg',
#  'person_without_helmet (100).jpg',
#  'person_without_helmet (101).jpg',
#  'person_without_helmet (102).jpg',
#  'person_without_helmet (103).jpg',
#  'person_without_helmet (104).jpg',
#  'person_without_helmet (105).jpg',
#  'person_without_helmet (106).jpg',
#  'person_without_helmet (107).jpg',
#  'person_without_helmet (108).jpg',
#  'person_without_helmet (109).jpg',
#  'person_without_helmet (11).jpg',
#  'person_without_helmet (110).jpg',
#  'person_without_helmet (111).jpg',
#  'person_without_helmet (112).jpg',
#  'person_without_helmet (113).jpg',
#  'person_without_helmet (114).jpg',
#  'person_without_helmet (115).jpg',
#  'person_without_helmet (116).jpg',
#  'person_without_helmet (117).jpg',
#  'person_without_helmet (118).jpg',
#  'person_without_helmet (119).jpg',
#  'person_without_helmet (12).jpg',
#  'person_without_helmet (120).jpg',
#  'person_without_helmet (121).jpg',
#  'person_without_helmet (122).jpg',
#  'person_without_helmet (123).jpg',
#  'person_without_helmet (124).jpg',
#  'person_without_helmet (126).jpg',
#  'person_without_helmet (127).jpg',
#  'person_without_helmet (128).jpg',
#  'person_without_helmet (129).jpg',
#  'person_without_helmet (13).jpg',
#  'person_without_helmet (130).jpg',
#  'person_without_helmet (131).jpg',
#  'person_without_helmet (132).jpg',
#  'person_without_helmet (133).jpg',
#  'person_without_helmet (134).jpg',
#  'person_without_helmet (135).jpg',
#  'person_without_helmet (136).jpg',
#  'person_without_helmet (137).jpg',
#  'person_without_helmet (138).jpg',
#  'person_without_helmet (139).jpg',
#  'person_without_helmet (14).jpg',
#  'person_without_helmet (140).jpg',
#  'person_without_helmet (141).jpg',
#  'person_without_helmet (142).jpg',
#  'person_without_helmet (143).jpg',
#  'person_without_helmet (144).jpg',
#  'person_without_helmet (145).jpg',
#  'person_without_helmet (146).jpg',
#  'person_without_helmet (147).jpg',
#  'person_without_helmet (148).jpg',
#  'person_without_helmet (149).jpg',
#  'person_without_helmet (155).jpg',
#  'person_without_helmet (156).jpg',
#  'person_without_helmet (157).jpg',
#  'person_without_helmet (158).jpg',
#  'person_without_helmet (159).jpg',
#  'person_without_helmet (160).jpg',
#  'person_without_helmet (161).jpg',
#  'person_without_helmet (162).jpg',
#  'person_without_helmet (163).jpg',
#  'person_without_helmet (164).jpg',
#  'person_without_helmet (165).jpg',
#  'person_without_helmet (166).jpg',
#  'person_without_helmet (167).jpg',
#  'person_without_helmet (168).jpg',
#  'person_without_helmet (169).jpg',
#  'person_without_helmet (170).jpg',
#  'person_without_helmet (171).jpg',
#  'person_without_helmet (172).jpg',
#  'person_without_helmet (173).jpg',
#  'person_without_helmet (174).jpg',
#  'person_without_helmet (175).jpg',
#  'person_without_helmet (176).jpg',
#  'person_without_helmet (177).jpg',
#  'person_without_helmet (180).jpg',
#  'person_without_helmet (181).jpg',
#  'person_without_helmet (182).jpg',
#  'person_without_helmet (183).jpg',
#  'person_without_helmet (184).jpg',
#  'person_without_helmet (185).jpg',
#  'person_without_helmet (186).jpg',
#  'person_without_helmet (187).jpg',
#  'person_without_helmet (188).jpg',
#  'person_without_helmet (189).jpg',
#  'person_without_helmet (190).jpg',
#  'person_without_helmet (191).jpg',
#  'person_without_helmet (192).jpg',
#  'person_without_helmet (193).jpg',
#  'person_without_helmet (194).jpg',
#  'person_without_helmet (195).jpg',
#  'person_without_helmet (196).jpg',
#  'person_without_helmet (197).jpg',
#  'person_without_helmet (198).jpg',
#  'person_without_helmet (199).jpg',
#  'person_without_helmet (200).jpg',
#  'person_without_helmet (201).jpg',
#  'person_without_helmet (202).jpg',
#  'person_without_helmet (203).jpg',
#  'person_without_helmet (204).jpg',
#  'person_without_helmet (205).jpg',
#  'person_without_helmet (206).jpg',
#  'person_without_helmet (207).jpg',
#  'person_without_helmet (208).jpg',
#  'person_without_helmet (209).jpg',
#  'person_without_helmet (210).jpg',
#  'person_without_helmet (211).jpg',
#  'person_without_helmet (212).jpg',
#  'person_without_helmet (213).jpg',
#  'person_without_helmet (214).jpg',
#  'person_without_helmet (215).jpg',
#  'person_without_helmet (216).jpg',
#  'person_without_helmet (217).jpg',
#  'person_without_helmet (218).jpg',
#  'person_without_helmet (219).jpg',
#  'person_without_helmet (220).jpg',
#  'person_without_helmet (221).jpg',
#  'person_without_helmet (222).jpg',
#  'person_without_helmet (223).jpg',
#  'person_without_helmet (224).jpg',
#  'person_without_helmet (225).jpg',
#  'person_without_helmet (226).jpg',
#  'person_without_helmet (227).jpg',
#  'person_without_helmet (228).jpg',
#  'person_without_helmet (229).jpg',
#  'person_without_helmet (230).jpg',
#  'person_without_helmet (231).jpg',
#  'person_without_helmet (232).jpg',
#  'person_without_helmet (233).jpg',
#  'person_without_helmet (234).jpg',
#  'person_without_helmet (235).jpg',
#  'person_without_helmet (236).jpg',
#  'person_without_helmet (237).jpg',
#  'person_without_helmet (238).jpg',
#  'person_without_helmet (239).jpg',
#  'person_without_helmet (240).jpg',
#  'person_without_helmet (241).jpg',
#  'person_without_helmet (242).jpg',
#  'person_without_helmet (243).jpg',
#  'person_without_helmet (244).jpg',
#  'person_without_helmet (245).jpg',
#  'person_without_helmet (246).jpg',
#  'person_without_helmet (247).jpg',
#  'person_without_helmet (248).jpg',
#  'person_without_helmet (249).jpg',
#  'person_without_helmet (250).jpg',
#  'person_without_helmet (251).jpg',
#  'person_without_helmet (252).jpg',
#  'person_without_helmet (253).jpg',
#  'person_without_helmet (254).jpg',
#  'person_without_helmet (255).jpg',
#  'person_without_helmet (256).jpg',
#  'person_without_helmet (257).jpg',
#  'person_without_helmet (258).jpg',
#  'person_without_helmet (259).jpg',
#  'person_without_helmet (260).jpg',
#  'person_without_helmet (261).jpg',
#  'person_without_helmet (262).jpg',
#  'person_without_helmet (263).jpg',
#  'person_without_helmet (264).jpg',
#  'person_without_helmet (265).jpg',
#  'person_without_helmet (266).jpg',
#  'person_without_helmet (267).jpg',
#  'person_without_helmet (268).jpg',
#  'person_without_helmet (269).jpg',
#  'person_without_helmet (270).jpg',
#  'person_without_helmet (271).jpg',
#  'person_without_helmet (272).jpg',
#  'person_without_helmet (273).jpg',
#  'person_without_helmet (274).jpg',
#  'person_without_helmet (275).jpg',
#  'person_without_helmet (276).jpg',
#  'person_without_helmet (277).jpg',
#  'person_without_helmet (278).jpg',
#  'person_without_helmet (279).jpg',
#  'person_without_helmet (280).jpg',
#  'person_without_helmet (281).jpg',
#  'person_without_helmet (282).jpg',
#  'person_without_helmet (283).jpg',
#  'person_without_helmet (284).jpg',
#  'person_without_helmet (285).jpg',
#  'person_without_helmet (286).jpg',
#  'person_without_helmet (287).jpg',
#  'person_without_helmet (288).jpg',
#  'person_without_helmet (289).jpg',
#  'person_without_helmet (290).jpg',
#  'person_without_helmet (291).jpg',
#  'person_without_helmet (292).jpg',
#  'person_without_helmet (293).jpg',
#  'person_without_helmet (294).jpg',
#  'person_without_helmet (295).jpg',
#  'person_without_helmet (296).jpg',
#  'person_without_helmet (297).jpg',
#  'person_without_helmet (3).jpg',
#  'person_without_helmet (30).jpg',
#  'person_without_helmet (31).jpg',
#  'person_without_helmet (32).jpg',
#  'person_without_helmet (33).jpg',
#  'person_without_helmet (34).jpg',
#  'person_without_helmet (35).jpg',
#  'person_without_helmet (36).jpg',
#  'person_without_helmet (37).jpg',
#  'person_without_helmet (38).jpg',
#  'person_without_helmet (39).jpg',
#  'person_without_helmet (4).jpg',
#  'person_without_helmet (40).jpg',
#  'person_without_helmet (41).jpg',
#  'person_without_helmet (42).jpg',
#  'person_without_helmet (43).jpg',
#  'person_without_helmet (44).jpg',
#  'person_without_helmet (45).jpg',
#  'person_without_helmet (46).jpg',
#  'person_without_helmet (47).jpg',
#  'person_without_helmet (48).jpg',
#  'person_without_helmet (49).jpg',
#  'person_without_helmet (5).jpg',
#  'person_without_helmet (50).jpg',
#  'person_without_helmet (51).jpg',
#  'person_without_helmet (52).jpg',
#  'person_without_helmet (53).jpg',
#  'person_without_helmet (54).jpg',
#  'person_without_helmet (55).jpg',
#  'person_without_helmet (56).jpg',
#  'person_without_helmet (57).jpg',
#  'person_without_helmet (58).jpg',
#  'person_without_helmet (59).jpg',
#  'person_without_helmet (6).jpg',
#  'person_without_helmet (60).jpg',
#  'person_without_helmet (61).jpg',
#  'person_without_helmet (62).jpg',
#  'person_without_helmet (63).jpg',
#  'person_without_helmet (64).jpg',
#  'person_without_helmet (65).jpg',
#  'person_without_helmet (66).jpg',
#  'person_without_helmet (67).jpg',
#  'person_without_helmet (68).jpg',
#  'person_without_helmet (69).jpg',
#  'person_without_helmet (7).jpg',
#  'person_without_helmet (70).jpg',
#  'person_without_helmet (71).jpg',
#  'person_without_helmet (72).jpg',
#  'person_without_helmet (73).jpg',
#  'person_without_helmet (74).jpg',
#  'person_without_helmet (75).jpg',
#  'person_without_helmet (76).jpg',
#  'person_without_helmet (77).jpg',
#  'person_without_helmet (78).jpg',
#  'person_without_helmet (79).jpg',
#  'person_without_helmet (8).jpg',
#  'person_without_helmet (80).jpg',
#  'person_without_helmet (81).jpg',
#  'person_without_helmet (82).jpg',
#  'person_without_helmet (83).jpg',
#  'person_without_helmet (84).jpg',
#  'person_without_helmet (85).jpg',
#  'person_without_helmet (86).jpg',
#  'person_without_helmet (87).jpg',
#  'person_without_helmet (88).jpg',
#  'person_without_helmet (89).jpg',
#  'person_without_helmet (9).jpg',
#  'person_without_helmet (90).jpg',
#  'person_without_helmet (91).jpg',
#  'person_without_helmet (92).jpg',
#  'person_without_helmet (93).jpg',
#  'person_without_helmet (94).jpg',
#  'person_without_helmet (96).jpg',
#  'person_without_helmet (97).jpg',
#  'person_without_helmet (98).jpg',
#  'worker (1).jpg',
#  'worker (10).jpg',
#  'worker (100).jpg',
#  'worker (101).jpg',
#  'worker (102).jpg',
#  'worker (103).jpg',
#  'worker (104).jpg',
#  'worker (105).jpg',
#  'worker (106).jpg',
#  'worker (107).jpg',
#  'worker (108).jpg',
#  'worker (109).jpg',
#  'worker (11).jpg',
#  'worker (110).jpg',
#  'worker (111).jpg',
#  'worker (112).jpg',
#  'worker (113).jpg',
#  'worker (114).jpg',
#  'worker (115).jpg',
#  'worker (116).jpg',
#  'worker (117).jpg',
#  'worker (118).jpg',
#  'worker (119).jpg',
#  'worker (12).jpg',
#  'worker (120).jpg',
#  'worker (121).jpg',
#  'worker (122).jpg',
#  'worker (123).jpg',
#  'worker (124).jpg',
#  'worker (125).jpg',
#  'worker (126).jpg',
#  'worker (127).jpg',
#  'worker (128).jpg',
#  'worker (129).jpg',
#  'worker (13).jpg',
#  'worker (130).jpg',
#  'worker (131).jpg',
#  'worker (132).jpg',
#  'worker (133).jpg',
#  'worker (134).jpg',
#  'worker (135).jpg',
#  'worker (136).jpg',
#  'worker (137).jpg',
#  'worker (138).jpg',
#  'worker (139).jpg',
#  'worker (14).jpg',
#  'worker (140).jpg',
#  'worker (141).jpg',
#  'worker (142).jpg',
#  'worker (143).jpg',
#  'worker (144).jpg',
#  'worker (145).jpg',
#  'worker (146).jpg',
#  'worker (147).jpg',
#  'worker (148).jpg',
#  'worker (149).jpg',
#  'worker (15).jpg',
#  'worker (150).jpg',
#  'worker (151).jpg',
#  'worker (152).jpg',
#  'worker (153).jpg',
#  'worker (154).jpg',
#  'worker (155).jpg',
#  'worker (156).jpg',
#  'worker (158).jpg',
#  'worker (159).jpg',
#  'worker (16).jpg',
#  'worker (160).jpg',
#  'worker (161).jpg',
#  'worker (162).jpg',
#  'worker (163).jpg',
#  'worker (164).jpg',
#  'worker (165).jpg',
#  'worker (166).jpg',
#  'worker (167).jpg',
#  'worker (168).jpg',
#  'worker (169).jpg',
#  'worker (17).jpg',
#  'worker (170).jpg',
#  'worker (171).jpg',
#  'worker (172).jpg',
#  'worker (173).jpg',
#  'worker (175).jpg',
#  'worker (176).jpg',
#  'worker (177).jpg',
#  'worker (178).jpg',
#  'worker (179).jpg',
#  'worker (18).jpg',
#  'worker (180).jpg',
#  'worker (181).jpg',
#  'worker (182).jpg',
#  'worker (183).jpg',
#  'worker (184).jpg',
#  'worker (185).jpg',
#  'worker (186).jpg',
#  'worker (187).jpg',
#  'worker (188).jpg',
#  'worker (189).jpg',
#  'worker (19).jpg',
#  'worker (190).jpg',
#  'worker (191).jpg',
#  'worker (192).jpg',
#  'worker (193).jpg',
#  'worker (194).jpg',
#  'worker (195).jpg',
#  'worker (196).jpg',
#  'worker (197).jpg',
#  'worker (198).jpg',
#  'worker (199).jpg',
#  'worker (2).jpg',
#  'worker (20).jpg',
#  'worker (200).jpg',
#  'worker (201).jpg',
#  'worker (203).jpg',
#  'worker (204).jpg',
#  'worker (205).jpg',
#  'worker (206).jpg',
#  'worker (207).jpg',
#  'worker (208).jpg',
#  'worker (209).jpg',
#  'worker (21).jpg',
#  'worker (211).jpg',
#  'worker (212).jpg',
#  'worker (213).jpg',
#  'worker (214).jpg',
#  'worker (215).jpg',
#  'worker (216).jpg',
#  'worker (217).jpg',
#  'worker (218).jpg',
#  'worker (219).jpg',
#  'worker (220).jpg',
#  'worker (221).jpg',
#  'worker (222).jpg',
#  'worker (223).jpg',
#  'worker (224).jpg',
#  'worker (225).jpg',
#  'worker (226).jpg',
#  'worker (227).jpg',
#  'worker (228).jpg',
#  'worker (229).jpg',
#  'worker (23).jpg',
#  'worker (230).jpg',
#  'worker (231).jpg',
#  'worker (232).jpg',
#  'worker (233).jpg',
#  'worker (234).jpg',
#  'worker (235).jpg',
#  'worker (236).jpg',
#  'worker (237).jpg',
#  'worker (238).jpg',
#  'worker (239).jpg',
#  'worker (24).jpg',
#  'worker (240).jpg',
#  'worker (241).jpg',
#  'worker (242).jpg',
#  'worker (243).jpg',
#  'worker (244).jpg',
#  'worker (245).jpg',
#  'worker (247).jpg',
#  'worker (248).jpg',
#  'worker (249).jpg',
#  'worker (25).jpg',
#  'worker (250).jpg',
#  'worker (251).jpg',
#  'worker (252).jpg',
#  'worker (253).jpg',
#  'worker (254).jpg',
#  'worker (255).jpg',
#  'worker (256).jpg',
#  'worker (257).jpg',
#  'worker (258).jpg',
#  'worker (259).jpg',
#  'worker (26).jpg',
#  'worker (260).jpg',
#  'worker (261).jpg',
#  'worker (262).jpg',
#  'worker (263).jpg',
#  'worker (264).jpg',
#  'worker (265).jpg',
#  'worker (266).jpg',
#  'worker (267).jpg',
#  'worker (268).jpg',
#  'worker (269).jpg',
#  'worker (27).jpg',
#  'worker (270).jpg',
#  'worker (271).jpg',
#  'worker (272).jpg',
#  'worker (273).jpg',
#  'worker (275).jpg',
#  'worker (276).jpg',
#  'worker (278).jpg',
#  'worker (279).jpg',
#  'worker (28).jpg',
#  'worker (280).jpg',
#  'worker (281).jpg',
#  'worker (282).jpg',
#  'worker (283).jpg',
#  'worker (284).jpg',
#  'worker (285).jpg',
#  'worker (289).jpg',
#  'worker (29).jpg',
#  'worker (290).jpg',
#  'worker (291).jpg',
#  'worker (293).jpg',
#  'worker (295).jpg',
#  'worker (296).jpg',
#  'worker (298).jpg',
#  'worker (299).jpg',
#  'worker (3).jpg',
#  'worker (30).jpg',
#  'worker (300).jpg',
#  'worker (301).jpg',
#  'worker (302).jpg',
#  'worker (304).jpg',
#  'worker (305).jpg',
#  'worker (306).jpg',
#  'worker (307).jpg',
#  'worker (308).jpg',
#  'worker (309).jpg',
#  'worker (310).jpg',
#  'worker (312).jpg',
#  'worker (313).jpg',
#  'worker (314).jpg',
#  'worker (315).jpg',
#  'worker (316).jpg',
#  'worker (317).jpg',
#  'worker (318).jpg',
#  'worker (319).jpg',
#  'worker (32).jpg',
#  'worker (320).jpg',
#  'worker (321).jpg',
#  'worker (322).jpg',
#  'worker (323).jpg',
#  'worker (324).jpg',
#  'worker (327).jpg',
#  'worker (328).jpg',
#  'worker (33).jpg',
#  'worker (330).jpg',
#  'worker (331).jpg',
#  'worker (332).jpg',
#  'worker (333).jpg',
#  'worker (334).jpg',
#  'worker (335).jpg',
#  'worker (337).jpg',
#  'worker (338).jpg',
#  'worker (339).jpg',
#  'worker (34).jpg',
#  'worker (340).jpg',
#  'worker (341).jpg',
#  'worker (345).jpg',
#  'worker (346).jpg',
#  'worker (348).jpg',
#  'worker (349).jpg',
#  'worker (35).jpg',
#  'worker (350).jpg',
#  'worker (351).jpg',
#  'worker (353).jpg',
#  'worker (354).jpg',
#  'worker (355).jpg',
#  'worker (357).jpg',
#  'worker (359).jpg',
#  'worker (36).jpg',
#  'worker (361).jpg',
#  'worker (362).jpg',
#  'worker (363).jpg',
#  'worker (364).jpg',
#  'worker (365).jpg',
#  'worker (366).jpg',
#  'worker (368).jpg',
#  'worker (369).jpg',
#  'worker (37).jpg',
#  'worker (371).jpg',
#  'worker (372).jpg',
#  'worker (373).jpg',
#  'worker (374).jpg',
#  'worker (375).jpg',
#  'worker (376).jpg',
#  'worker (377).jpg',
#  'worker (378).jpg',
#  'worker (379).jpg',
#  'worker (38).jpg',
#  'worker (380).jpg',
#  'worker (381).jpg',
#  'worker (382).jpg',
#  'worker (383).jpg',
#  'worker (384).jpg',
#  'worker (385).jpg',
#  'worker (386).jpg',
#  'worker (387).jpg',
#  'worker (388).jpg',
#  'worker (389).jpg',
#  'worker (39).jpg',
#  'worker (390).jpg',
#  'worker (391).jpg',
#  'worker (392).jpg',
#  'worker (393).jpg',
#  'worker (394).jpg',
#  'worker (395).jpg',
#  'worker (396).jpg',
#  'worker (397).jpg',
#  'worker (398).jpg',
#  'worker (399).jpg',
#  'worker (4).jpg',
#  'worker (40).jpg',
#  'worker (400).jpg',
#  'worker (401).jpg',
#  'worker (402).jpg',
#  'worker (403).jpg',
#  'worker (404).jpg',
#  'worker (405).jpg',
#  'worker (406).jpg',
#  'worker (407).jpg',
#  'worker (408).jpg',
#  'worker (409).jpg',
#  'worker (41).jpg',
#  'worker (410).jpg',
#  'worker (411).jpg',
#  'worker (412).jpg',
#  'worker (413).jpg',
#  'worker (414).jpg',
#  'worker (415).jpg',
#  'worker (416).jpg',
#  'worker (417).jpg',
#  'worker (418).jpg',
#  'worker (419).jpg',
#  'worker (42).jpg',
#  'worker (420).jpg',
#  'worker (421).jpg',
#  'worker (422).jpg',
#  'worker (423).jpg',
#  'worker (424).jpg',
#  'worker (425).jpg',
#  'worker (426).jpg',
#  'worker (427).jpg',
#  'worker (428).jpg',
#  'worker (429).jpg',
#  'worker (43).jpg',
#  'worker (430).jpg',
#  'worker (431).jpg',
#  'worker (432).jpg',
#  'worker (433).jpg',
#  'worker (434).jpg',
#  'worker (435).jpg',
#  'worker (436).jpg',
#  'worker (437).jpg',
#  'worker (438).jpg',
#  'worker (439).jpg',
#  'worker (44).jpg',
#  'worker (440).jpg',
#  'worker (441).jpg',
#  'worker (442).jpg',
#  'worker (443).jpg',
#  'worker (444).jpg',
#  'worker (445).jpg',
#  'worker (446).jpg',
#  'worker (447).jpg',
#  'worker (448).jpg',
#  'worker (449).jpg',
#  'worker (45).jpg',
#  'worker (450).jpg',
#  'worker (451).jpg',
#  'worker (452).jpg',
#  'worker (453).jpg',
#  'worker (454).jpg',
#  'worker (455).jpg',
#  'worker (456).jpg',
#  'worker (457).jpg',
#  'worker (458).jpg',
#  'worker (459).jpg',
#  'worker (46).jpg',
#  'worker (460).jpg',
#  'worker (461).jpg',
#  'worker (462).jpg',
#  'worker (463).jpg',
#  'worker (464).jpg',
#  'worker (465).jpg',
#  'worker (466).jpg',
#  'worker (467).jpg',
#  'worker (468).jpg',
#  'worker (469).jpg',
#  'worker (47).jpg',
#  'worker (470).jpg',
#  'worker (471).jpg',
#  'worker (472).jpg',
#  'worker (473).jpg',
#  'worker (474).jpg',
#  'worker (475).jpg',
#  'worker (476).jpg',
#  'worker (477).jpg',
#  'worker (478).jpg',
#  'worker (479).jpg',
#  'worker (48).jpg',
#  'worker (480).jpg',
#  'worker (481).jpg',
#  'worker (482).jpg',
#  'worker (483).jpg',
#  'worker (484).jpg',
#  'worker (485).jpg',
#  'worker (486).jpg',
#  'worker (487).jpg',
#  'worker (488).jpg',
#  'worker (489).jpg',
#  'worker (49).jpg',
#  'worker (490).jpg',
#  'worker (491).jpg',
#  'worker (492).jpg',
#  'worker (493).jpg',
#  'worker (494).jpg',
#  'worker (495).jpg',
#  'worker (496).jpg',
#  'worker (497).jpg',
#  'worker (498).jpg',
#  'worker (499).jpg',
#  'worker (5).jpg',
#  'worker (50).jpg',
#  'worker (500).jpg',
#  'worker (501).jpg',
#  'worker (502).jpg',
#  'worker (503).jpg',
#  'worker (504).jpg',
#  'worker (505).jpg',
#  'worker (506).jpg',
#  'worker (507).jpg',
#  'worker (508).jpg',
#  'worker (509).jpg',
#  'worker (51).jpg',
#  'worker (510).jpg',
#  'worker (511).jpg',
#  'worker (512).jpg',
#  'worker (513).jpg',
#  'worker (514).jpg',
#  'worker (515).jpg',
#  'worker (516).jpg',
#  'worker (517).jpg',
#  'worker (518).jpg',
#  'worker (519).jpg',
#  'worker (52).jpg',
#  'worker (520).jpg',
#  'worker (521).jpg',
#  'worker (522).jpg',
#  'worker (523).jpg',
#  'worker (524).jpg',
#  'worker (525).jpg',
#  'worker (526).jpg',
#  'worker (527).jpg',
#  'worker (528).jpg',
#  'worker (529).jpg',
#  'worker (53).jpg',
#  'worker (530).jpg',
#  'worker (532).jpg',
#  'worker (533).jpg',
#  'worker (534).jpg',
#  'worker (535).jpg',
#  'worker (536).jpg',
#  'worker (537).jpg',
#  'worker (538).jpg',
#  'worker (539).jpg',
#  'worker (54).jpg',
#  'worker (540).jpg',
#  'worker (541).jpg',
#  'worker (542).jpg',
#  'worker (543).jpg',
#  'worker (544).jpg',
#  'worker (547).jpg',
#  'worker (548).jpg',
#  'worker (549).jpg',
#  'worker (55).jpg',
#  'worker (550).jpg',
#  'worker (551).jpg',
#  'worker (552).jpg',
#  'worker (553).jpg',
#  'worker (554).jpg',
#  'worker (555).jpg',
#  'worker (556).jpg',
#  'worker (557).jpg',
#  'worker (558).jpg',
#  'worker (559).jpg',
#  'worker (56).jpg',
#  'worker (560).jpg',
#  'worker (561).jpg',
#  'worker (562).jpg',
#  'worker (563).jpg',
#  'worker (564).jpg',
#  'worker (565).jpg',
#  'worker (566).jpg',
#  'worker (567).jpg',
#  'worker (568).jpg',
#  'worker (569).jpg',
#  'worker (57).jpg',
#  'worker (570).jpg',
#  'worker (571).jpg',
#  'worker (572).jpg',
#  'worker (573).jpg',
#  'worker (574).jpg',
#  'worker (575).jpg',
#  'worker (576).jpg',
#  'worker (577).jpg',
#  'worker (578).jpg',
#  'worker (579).jpg',
#  'worker (58).jpg',
#  'worker (580).jpg',
#  'worker (581).jpg',
#  'worker (582).jpg',
#  'worker (583).jpg',
#  'worker (584).jpg',
#  'worker (585).jpg',
#  'worker (586).jpg',
#  'worker (587).jpg',
#  'worker (588).jpg',
#  'worker (589).jpg',
#  'worker (59).jpg',
#  'worker (590).jpg',
#  'worker (591).jpg',
#  'worker (592).jpg',
#  'worker (593).jpg',
#  'worker (594).jpg',
#  'worker (595).jpg',
#  'worker (596).jpg',
#  'worker (597).jpg',
#  'worker (598).jpg',
#  'worker (599).jpg',
#  'worker (6).jpg',
#  'worker (60).jpg',
#  'worker (600).jpg',
#  'worker (601).jpg',
#  'worker (602).jpg',
#  'worker (603).jpg',
#  'worker (604).jpg',
#  'worker (605).jpg',
#  'worker (606).jpg',
#  'worker (607).jpg',
#  'worker (608).jpg',
#  'worker (609).jpg',
#  'worker (61).jpg',
#  'worker (610).jpg',
#  'worker (611).jpg',
#  'worker (612).jpg',
#  'worker (613).jpg',
#  'worker (614).jpg',
#  'worker (615).jpg',
#  'worker (616).jpg',
#  'worker (617).jpg',
#  'worker (618).jpg',
#  'worker (619).jpg',
#  'worker (62).jpg',
#  'worker (620).jpg',
#  'worker (621).jpg',
#  'worker (622).jpg',
#  'worker (623).jpg',
#  'worker (624).jpg',
#  'worker (625).jpg',
#  'worker (626).jpg',
#  'worker (627).jpg',
#  'worker (628).jpg',
#  'worker (629).jpg',
#  'worker (63).jpg',
#  'worker (630).jpg',
#  'worker (631).jpg',
#  'worker (632).jpg',
#  'worker (633).jpg',
#  'worker (634).jpg',
#  'worker (635).jpg',
#  'worker (636).jpg',
#  'worker (637).jpg',
#  'worker (638).jpg',
#  'worker (639).jpg',
#  'worker (64).jpg',
#  'worker (640).jpg',
#  'worker (641).jpg',
#  'worker (642).jpg',
#  'worker (643).jpg',
#  'worker (644).jpg',
#  'worker (645).jpg',
#  'worker (646).jpg',
#  'worker (647).jpg',
#  'worker (648).jpg',
#  'worker (649).jpg',
#  ...]

# %%
filename=[]
for x in b:
    
    filename.append('/kaggle/input/helmet/keras-yolo2-master/train_image_folder'+ '/'+ x)

# %%
filename
# Out:
# ['/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_001.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_002.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_003.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_004.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_005.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_007.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_008.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_011.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_012.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_013.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_014.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_015.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_016.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_017.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_018.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_019.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_020.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_021.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_022.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_023.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_024.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_025.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_026.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_028.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_029.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_030.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_032.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_035.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_036.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_037.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_038.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_039.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_040.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_041.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_042.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_043.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_044.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_045.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_046.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_047.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_048.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_049.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_050.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_051.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_052.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_053.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_054.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_055.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_056.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_057.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_058.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_059.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_060.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_061.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_062.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_063.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_064.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_065.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_066.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_067.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_068.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_069.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_070.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_071.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_072.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_073.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_074.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_075.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_076.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_077.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_078.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_079.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_080.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_081.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_082.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_083.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_084.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_085.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_086.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_087.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_088.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_089.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_090.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_091.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_093.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_094.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_095.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_096.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_097.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_098.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_099.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_100.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_101.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_102.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_103.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_104.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_105.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_106.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_107.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_108.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_109.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_110.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_111.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_112.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_113.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_114.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_115.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_116.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_117.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_118.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_120.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_121.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_122.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_123.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_124.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_125.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_126.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_127.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_128.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_129.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_130.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_132.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_133.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_134.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_135.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_136.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_138.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_139.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_142.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_143.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_144.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_151.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_152.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_153.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_154.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_155.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_156.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_158.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_159.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_160.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_162.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_163.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_169.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_170.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_171.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_172.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_173.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_176.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_177.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_178.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_179.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_181.jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (1).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (10).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (100).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (101).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (102).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (103).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (104).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (105).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (106).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (107).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (108).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (109).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (11).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (110).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (111).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (112).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (113).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (114).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (115).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (116).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (117).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (118).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (119).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (12).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (120).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (121).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (122).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (123).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (124).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (126).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (127).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (128).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (129).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (13).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (130).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (131).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (132).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (133).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (134).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (135).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (136).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (137).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (138).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (139).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (14).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (140).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (141).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (142).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (143).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (144).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (145).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (146).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (147).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (148).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (149).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (155).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (156).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (157).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (158).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (159).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (160).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (161).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (162).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (163).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (164).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (165).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (166).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (167).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (168).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (169).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (170).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (171).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (172).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (173).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (174).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (175).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (176).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (177).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (180).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (181).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (182).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (183).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (184).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (185).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (186).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (187).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (188).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (189).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (190).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (191).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (192).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (193).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (194).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (195).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (196).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (197).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (198).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (199).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (200).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (201).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (202).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (203).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (204).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (205).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (206).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (207).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (208).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (209).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (210).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (211).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (212).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (213).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (214).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (215).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (216).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (217).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (218).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (219).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (220).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (221).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (222).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (223).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (224).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (225).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (226).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (227).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (228).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (229).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (230).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (231).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (232).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (233).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (234).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (235).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (236).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (237).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (238).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (239).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (240).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (241).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (242).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (243).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (244).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (245).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (246).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (247).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (248).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (249).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (250).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (251).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (252).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (253).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (254).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (255).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (256).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (257).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (258).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (259).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (260).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (261).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (262).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (263).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (264).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (265).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (266).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (267).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (268).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (269).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (270).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (271).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (272).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (273).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (274).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (275).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (276).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (277).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (278).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (279).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (280).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (281).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (282).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (283).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (284).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (285).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (286).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (287).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (288).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (289).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (290).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (291).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (292).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (293).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (294).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (295).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (296).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (297).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (3).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (30).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (31).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (32).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (33).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (34).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (35).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (36).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (37).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (38).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (39).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (4).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (40).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (41).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (42).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (43).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (44).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (45).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (46).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (47).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (48).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (49).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (5).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (50).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (51).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (52).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (53).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (54).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (55).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (56).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (57).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (58).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (59).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (6).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (60).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (61).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (62).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (63).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (64).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (65).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (66).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (67).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (68).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (69).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (7).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (70).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (71).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (72).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (73).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (74).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (75).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (76).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (77).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (78).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (79).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (8).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (80).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (81).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (82).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (83).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (84).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (85).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (86).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (87).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (88).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (89).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (9).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (90).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (91).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (92).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (93).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (94).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (96).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (97).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (98).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (1).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (10).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (100).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (101).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (102).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (103).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (104).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (105).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (106).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (107).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (108).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (109).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (11).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (110).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (111).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (112).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (113).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (114).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (115).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (116).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (117).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (118).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (119).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (12).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (120).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (121).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (122).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (123).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (124).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (125).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (126).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (127).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (128).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (129).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (13).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (130).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (131).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (132).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (133).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (134).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (135).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (136).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (137).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (138).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (139).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (14).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (140).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (141).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (142).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (143).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (144).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (145).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (146).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (147).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (148).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (149).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (15).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (150).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (151).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (152).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (153).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (154).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (155).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (156).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (158).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (159).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (16).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (160).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (161).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (162).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (163).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (164).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (165).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (166).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (167).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (168).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (169).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (17).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (170).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (171).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (172).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (173).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (175).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (176).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (177).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (178).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (179).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (18).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (180).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (181).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (182).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (183).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (184).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (185).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (186).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (187).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (188).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (189).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (19).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (190).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (191).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (192).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (193).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (194).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (195).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (196).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (197).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (198).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (199).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (2).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (20).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (200).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (201).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (203).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (204).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (205).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (206).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (207).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (208).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (209).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (21).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (211).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (212).jpg',
# ...
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (467).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (468).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (469).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (47).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (470).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (471).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (472).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (473).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (474).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (475).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (476).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (477).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (478).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (479).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (48).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (480).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (481).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (482).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (483).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (484).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (485).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (486).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (487).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (488).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (489).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (49).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (490).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (491).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (492).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (493).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (494).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (495).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (496).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (497).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (498).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (499).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (5).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (50).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (500).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (501).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (502).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (503).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (504).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (505).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (506).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (507).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (508).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (509).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (51).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (510).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (511).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (512).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (513).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (514).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (515).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (516).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (517).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (518).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (519).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (52).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (520).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (521).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (522).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (523).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (524).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (525).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (526).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (527).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (528).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (529).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (53).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (530).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (532).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (533).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (534).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (535).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (536).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (537).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (538).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (539).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (54).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (540).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (541).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (542).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (543).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (544).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (547).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (548).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (549).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (55).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (550).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (551).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (552).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (553).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (554).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (555).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (556).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (557).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (558).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (559).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (56).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (560).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (561).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (562).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (563).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (564).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (565).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (566).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (567).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (568).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (569).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (57).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (570).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (571).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (572).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (573).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (574).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (575).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (576).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (577).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (578).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (579).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (58).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (580).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (581).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (582).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (583).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (584).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (585).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (586).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (587).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (588).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (589).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (59).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (590).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (591).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (592).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (593).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (594).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (595).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (596).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (597).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (598).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (599).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (6).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (60).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (600).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (601).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (602).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (603).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (604).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (605).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (606).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (607).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (608).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (609).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (61).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (610).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (611).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (612).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (613).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (614).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (615).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (616).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (617).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (618).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (619).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (62).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (620).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (621).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (622).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (623).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (624).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (625).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (626).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (627).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (628).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (629).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (63).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (630).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (631).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (632).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (633).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (634).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (635).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (636).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (637).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (638).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (639).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (64).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (640).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (641).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (642).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (643).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (644).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (645).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (646).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (647).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (648).jpg',
#  '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (649).jpg',
#  ...]

# %%
df = pd.DataFrame({'filename': filename, 'xmin': xmin,'ymin':ymin,'xmax':xmax,'ymax':ymax })

# %%
df.head()
# Out:
#                                             filename xmin ymin xmax ymax
# 0  /kaggle/input/helmet/keras-yolo2-master/train_...   30   57  250  322
# 1  /kaggle/input/helmet/keras-yolo2-master/train_...  205   16  420  277
# 2  /kaggle/input/helmet/keras-yolo2-master/train_...  271   86  435  292
# 3  /kaggle/input/helmet/keras-yolo2-master/train_...   66   19  246  417
# 4  /kaggle/input/helmet/keras-yolo2-master/train_...   91   60  224  451

# %%
df['filename'][0]
# Out:
# '/kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_001.jpg'

# %%
df['class'] = 'helmet'

# %%
ANNOTATIONS_FILE = 'annotations.csv'
CLASSES_FILE = 'classes.csv'

# %%
df.to_csv(ANNOTATIONS_FILE, index=False, header=None)

# %%
classes = set(['helmet'])

with open(CLASSES_FILE, 'w') as f:
    for i, line in enumerate(sorted(classes)):
        f.write('{},{}\n'.format(line,i))

# %%
# !head classes.csv
# Out:
# helmet,0

# %%
# !head annotations.csv
# Out:
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_001.jpg,30,57,250,322,helmet
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_002.jpg,205,16,420,277,helmet
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_003.jpg,271,86,435,292,helmet
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_004.jpg,66,19,246,417,helmet
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_005.jpg,91,60,224,451,helmet
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_007.jpg,159,15,396,302,helmet
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_008.jpg,211,28,314,232,helmet
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_011.jpg,471,207,535,483,helmet
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_012.jpg,219,19,335,298,helmet
# /kaggle/input/helmet/keras-yolo2-master/train_image_folder/applauding_013.jpg,2,4,149,436,helmet

# %%
PRETRAINED_MODEL = './snapshots/_pretrained_model.h5'

URL_MODEL = 'https://github.com/fizyr/keras-retinanet/releases/download/0.5.1/resnet50_oid_v1.0.0.h5'
urllib.request.urlretrieve(URL_MODEL, PRETRAINED_MODEL)

print('Downloaded pretrained model to ' + PRETRAINED_MODEL)
# Out:
# Downloaded pretrained model to ./snapshots/_pretrained_model.h5

# %%
EPOCHS = 10
BATCH_SIZE=8
STEPS = 100 #len(train_df)//BATCH_SIZE #Keeping it small for faster commit
LR=1e-3

# %%
# !keras_retinanet/bin/train.py --random-transform --weights {PRETRAINED_MODEL} --lr {LR} --batch-size {BATCH_SIZE} --steps {STEPS} --epochs {EPOCHS} --no-resize csv annotations.csv classes.csv
# Out:
# 2020-09-09 04:08:49.472131: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Creating model, this may take a second...
# 2020-09-09 04:08:52.717748: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-09-09 04:08:53.046710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-09 04:08:53.047418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-09-09 04:08:53.047480: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-09 04:08:53.140113: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-09-09 04:08:53.200265: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-09-09 04:08:53.212448: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-09-09 04:08:53.297615: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-09-09 04:08:53.310629: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-09-09 04:08:53.479724: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-09-09 04:08:53.479921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-09 04:08:53.480733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-09 04:08:53.481359: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-09-09 04:08:53.481707: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-09-09 04:08:53.505276: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2000160000 Hz
# 2020-09-09 04:08:53.505530: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6099f5950 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-09 04:08:53.505567: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-09-09 04:08:53.507209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-09 04:08:53.507873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-09-09 04:08:53.507921: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-09 04:08:53.507969: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-09-09 04:08:53.507998: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-09-09 04:08:53.508025: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-09-09 04:08:53.508050: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-09-09 04:08:53.508075: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-09-09 04:08:53.508099: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-09-09 04:08:53.508203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-09 04:08:53.508937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-09 04:08:53.509539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-09-09 04:08:53.511100: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-09 04:08:55.009229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-09 04:08:55.009300: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-09-09 04:08:55.009338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-09-09 04:08:55.012599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-09 04:08:55.013452: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-09 04:08:55.014206: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-09 04:08:55.014851: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14968 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-09-09 04:08:55.022547: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6218dbe90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-09-09 04:08:55.022582: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# Model: "retinanet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9408        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_relu (Activation (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2a_branch2b (ZeroPadding (None, None, None, 6 0           res2a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36864       padding2a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_relu (Activation (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16384       res2a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16384       pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_relu (Activation)         (None, None, None, 2 0           res2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16384       res2a_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_relu (Activation (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2b_branch2b (ZeroPadding (None, None, None, 6 0           res2b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36864       padding2b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_relu (Activation (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16384       res2b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# res2b (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_relu (Activation)         (None, None, None, 2 0           res2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16384       res2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_relu (Activation (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2c_branch2b (ZeroPadding (None, None, None, 6 0           res2c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36864       padding2c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_relu (Activation (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16384       res2c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# res2c (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  res2b_relu[0][0]
# __________________________________________________________________________________________________
# res2c_relu (Activation)         (None, None, None, 2 0           res2c[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32768       res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_relu (Activation (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3a_branch2b (ZeroPadding (None, None, None, 1 0           res3a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147456      padding3a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_relu (Activation (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 65536       res3a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131072      res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_relu (Activation)         (None, None, None, 5 0           res3a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65536       res3a_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_relu (Activation (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3b_branch2b (ZeroPadding (None, None, None, 1 0           res3b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147456      padding3b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_relu (Activation (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 65536       res3b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_relu (Activation)         (None, None, None, 5 0           res3b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65536       res3b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_relu (Activation (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3c_branch2b (ZeroPadding (None, None, None, 1 0           res3c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147456      padding3c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_relu (Activation (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 65536       res3c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# res3c (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  res3b_relu[0][0]
# __________________________________________________________________________________________________
# res3c_relu (Activation)         (None, None, None, 5 0           res3c[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65536       res3c_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_relu (Activation (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3d_branch2b (ZeroPadding (None, None, None, 1 0           res3d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147456      padding3d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_relu (Activation (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 65536       res3d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# res3d (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  res3c_relu[0][0]
# __________________________________________________________________________________________________
# res3d_relu (Activation)         (None, None, None, 5 0           res3d[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131072      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_relu (Activation (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4a_branch2b (ZeroPadding (None, None, None, 2 0           res4a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 589824      padding4a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_relu (Activation (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 262144      res4a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 524288      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_relu (Activation)         (None, None, None, 1 0           res4a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262144      res4a_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_relu (Activation (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4b_branch2b (ZeroPadding (None, None, None, 2 0           res4b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 589824      padding4b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_relu (Activation (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 262144      res4b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_relu (Activation)         (None, None, None, 1 0           res4b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262144      res4b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_relu (Activation (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4c_branch2b (ZeroPadding (None, None, None, 2 0           res4c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 589824      padding4c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_relu (Activation (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 262144      res4c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# res4c (Add)                     (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  res4b_relu[0][0]
# __________________________________________________________________________________________________
# res4c_relu (Activation)         (None, None, None, 1 0           res4c[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262144      res4c_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_relu (Activation (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4d_branch2b (ZeroPadding (None, None, None, 2 0           res4d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 589824      padding4d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b_relu (Activation (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 262144      res4d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# res4d (Add)                     (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  res4c_relu[0][0]
# __________________________________________________________________________________________________
# res4d_relu (Activation)         (None, None, None, 1 0           res4d[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262144      res4d_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a_relu (Activation (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4e_branch2b (ZeroPadding (None, None, None, 2 0           res4e_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 589824      padding4e_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b_relu (Activation (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 262144      res4e_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# res4e (Add)                     (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  res4d_relu[0][0]
# __________________________________________________________________________________________________
# res4e_relu (Activation)         (None, None, None, 1 0           res4e[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262144      res4e_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a_relu (Activation (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4f_branch2b (ZeroPadding (None, None, None, 2 0           res4f_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 589824      padding4f_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b_relu (Activation (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 262144      res4f_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# res4f (Add)                     (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  res4e_relu[0][0]
# __________________________________________________________________________________________________
# res4f_relu (Activation)         (None, None, None, 1 0           res4f[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524288      res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_relu (Activation (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5a_branch2b (ZeroPadding (None, None, None, 5 0           res5a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_relu (Activation (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1048576     res5a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2097152     res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a (Add)                     (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_relu (Activation)         (None, None, None, 2 0           res5a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1048576     res5a_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_relu (Activation (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5b_branch2b (ZeroPadding (None, None, None, 5 0           res5b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_relu (Activation (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1048576     res5b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# res5b (Add)                     (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  res5a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_relu (Activation)         (None, None, None, 2 0           res5b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1048576     res5b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_relu (Activation (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5c_branch2b (ZeroPadding (None, None, None, 5 0           res5c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_relu (Activation (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1048576     res5c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# res5c (Add)                     (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  res5b_relu[0][0]
# __________________________________________________________________________________________________
# res5c_relu (Activation)         (None, None, None, 2 0           res5c[0][0]
# __________________________________________________________________________________________________
# C5_reduced (Conv2D)             (None, None, None, 2 524544      res5c_relu[0][0]
# __________________________________________________________________________________________________
# P5_upsampled (UpsampleLike)     (None, None, None, 2 0           C5_reduced[0][0]
#                                                                  res4f_relu[0][0]
# __________________________________________________________________________________________________
# C4_reduced (Conv2D)             (None, None, None, 2 262400      res4f_relu[0][0]
# __________________________________________________________________________________________________
# P4_merged (Add)                 (None, None, None, 2 0           P5_upsampled[0][0]
#                                                                  C4_reduced[0][0]
# __________________________________________________________________________________________________
# P4_upsampled (UpsampleLike)     (None, None, None, 2 0           P4_merged[0][0]
#                                                                  res3d_relu[0][0]
# __________________________________________________________________________________________________
# C3_reduced (Conv2D)             (None, None, None, 2 131328      res3d_relu[0][0]
# __________________________________________________________________________________________________
# P6 (Conv2D)                     (None, None, None, 2 4718848     res5c_relu[0][0]
# __________________________________________________________________________________________________
# P3_merged (Add)                 (None, None, None, 2 0           P4_upsampled[0][0]
#                                                                  C3_reduced[0][0]
# __________________________________________________________________________________________________
# C6_relu (Activation)            (None, None, None, 2 0           P6[0][0]
# __________________________________________________________________________________________________
# P3 (Conv2D)                     (None, None, None, 2 590080      P3_merged[0][0]
# __________________________________________________________________________________________________
# P4 (Conv2D)                     (None, None, None, 2 590080      P4_merged[0][0]
# __________________________________________________________________________________________________
# P5 (Conv2D)                     (None, None, None, 2 590080      C5_reduced[0][0]
# __________________________________________________________________________________________________
# P7 (Conv2D)                     (None, None, None, 2 590080      C6_relu[0][0]
# __________________________________________________________________________________________________
# regression_submodel (Functional (None, None, 4)      2443300     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# classification_submodel (Functi (None, None, 1)      2381065     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# regression (Concatenate)        (None, None, 4)      0           regression_submodel[0][0]
#                                                                  regression_submodel[1][0]
#                                                                  regression_submodel[2][0]
#                                                                  regression_submodel[3][0]
#                                                                  regression_submodel[4][0]
# __________________________________________________________________________________________________
# classification (Concatenate)    (None, None, 1)      0           classification_submodel[0][0]
#                                                                  classification_submodel[1][0]
#                                                                  classification_submodel[2][0]
#                                                                  classification_submodel[3][0]
#                                                                  classification_submodel[4][0]
# ==================================================================================================
# Total params: 36,382,957
# Trainable params: 36,276,717
# Non-trainable params: 106,240
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# 2020-09-09 04:09:07.792338: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-09-09 04:09:10.209002: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
#  45/100 [============>.................] - ETA: 40s - loss: 121.1357 - regression_loss: 2.9923 - classification_loss: 118.1433keras_retinanet/bin/../../keras_retinanet/preprocessing/generator.py:181: UserWarning: Image /kaggle/input/helmet/keras-yolo2-master/train_image_folder/person_without_helmet (188).jpg with id 238 (shape (200, 200, 3)) contains the following invalid boxes: [[ 66.  31. 130. 259.]].
#   annotations['bboxes'][invalid_indices, :]
# 100/100 [==============================] - ETA: 0s - loss: 57.2643 - regression_loss: 2.7426 - classification_loss: 54.5217
# Epoch 00001: saving model to ./snapshots/resnet50_csv_01.h5
# 100/100 [==============================] - 66s 661ms/step - loss: 57.2643 - regression_loss: 2.7426 - classification_loss: 54.5217
# Epoch 2/10
#  71/100 [====================>.........] - ETA: 9s - loss: 59.6965 - regression_loss: 3.0848 - classification_loss: 56.6118keras_retinanet/bin/../../keras_retinanet/preprocessing/generator.py:181: UserWarning: Image /kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (184).jpg with id 515 (shape (175, 288, 3)) contains the following invalid boxes: [[186.  11. 268. 178.]].
#   annotations['bboxes'][invalid_indices, :]
#  81/100 [=======================>......] - ETA: 6s - loss: 53.0870 - regression_loss: 3.0210 - classification_loss: 50.0659keras_retinanet/bin/../../keras_retinanet/preprocessing/generator.py:181: UserWarning: Image /kaggle/input/helmet/keras-yolo2-master/train_image_folder/worker (354).jpg with id 680 (shape (194, 259, 3)) contains the following invalid boxes: [[  1.   7. 177. 254.]].
#   annotations['bboxes'][invalid_indices, :]
# 100/100 [==============================] - ETA: 0s - loss: 44.1687 - regression_loss: 2.9311 - classification_loss: 41.2376
# Epoch 00002: saving model to ./snapshots/resnet50_csv_02.h5
# 100/100 [==============================] - 35s 352ms/step - loss: 44.1687 - regression_loss: 2.9311 - classification_loss: 41.2376
# Epoch 3/10
# 100/100 [==============================] - ETA: 0s - loss: 11.4096 - regression_loss: 2.5814 - classification_loss: 8.8282
# Epoch 00003: saving model to ./snapshots/resnet50_csv_03.h5
# 100/100 [==============================] - 32s 317ms/step - loss: 11.4096 - regression_loss: 2.5814 - classification_loss: 8.8282
# Epoch 4/10
# 100/100 [==============================] - ETA: 0s - loss: 16.7660 - regression_loss: 2.5355 - classification_loss: 14.2305
# Epoch 00004: saving model to ./snapshots/resnet50_csv_04.h5
# 100/100 [==============================] - 27s 270ms/step - loss: 16.7660 - regression_loss: 2.5355 - classification_loss: 14.2305
# Epoch 5/10
# 100/100 [==============================] - ETA: 0s - loss: 4.1023 - regression_loss: 2.4559 - classification_loss: 1.6464
# Epoch 00005: saving model to ./snapshots/resnet50_csv_05.h5
# 100/100 [==============================] - 22s 221ms/step - loss: 4.1023 - regression_loss: 2.4559 - classification_loss: 1.6464
# Epoch 6/10
# 100/100 [==============================] - ETA: 0s - loss: 17.5748 - regression_loss: 2.6799 - classification_loss: 14.8949
# Epoch 00006: saving model to ./snapshots/resnet50_csv_06.h5
# 100/100 [==============================] - 25s 251ms/step - loss: 17.5748 - regression_loss: 2.6799 - classification_loss: 14.8949
# Epoch 7/10
# 100/100 [==============================] - ETA: 0s - loss: 14.3210 - regression_loss: 2.4503 - classification_loss: 11.8707
# Epoch 00007: saving model to ./snapshots/resnet50_csv_07.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 100/100 [==============================] - 25s 255ms/step - loss: 14.3210 - regression_loss: 2.4503 - classification_loss: 11.8707
# Epoch 8/10
# 100/100 [==============================] - ETA: 0s - loss: 5.4837 - regression_loss: 2.3622 - classification_loss: 3.1215
# Epoch 00008: saving model to ./snapshots/resnet50_csv_08.h5
# 100/100 [==============================] - 23s 231ms/step - loss: 5.4837 - regression_loss: 2.3622 - classification_loss: 3.1215
# Epoch 9/10
# 100/100 [==============================] - ETA: 0s - loss: 2.8047 - regression_loss: 2.3103 - classification_loss: 0.4943
# Epoch 00009: saving model to ./snapshots/resnet50_csv_09.h5
# 100/100 [==============================] - 27s 271ms/step - loss: 2.8047 - regression_loss: 2.3103 - classification_loss: 0.4943
# Epoch 10/10
# 100/100 [==============================] - ETA: 0s - loss: 2.7288 - regression_loss: 2.2510 - classification_loss: 0.4778
# Epoch 00010: saving model to ./snapshots/resnet50_csv_10.h5
# 100/100 [==============================] - 25s 246ms/step - loss: 2.7288 - regression_loss: 2.2510 - classification_loss: 0.4778

# %%
# !ls snapshots
# Out:
# _pretrained_model.h5  resnet50_csv_04.h5  resnet50_csv_08.h5
# resnet50_csv_01.h5    resnet50_csv_05.h5  resnet50_csv_09.h5
# resnet50_csv_02.h5    resnet50_csv_06.h5  resnet50_csv_10.h5
# resnet50_csv_03.h5    resnet50_csv_07.h5

# %%
model_path = os.path.join('snapshots', sorted(os.listdir('snapshots'), reverse=True)[0])

# %%
model = models.load_model(model_path, backbone_name='resnet50')
model = models.convert_model(model)

# %%
li=os.listdir('/kaggle/input/test-helmet/test_images')
li[:5]
# Out:
# ['worker (227).jpg',
#  'worker (243).jpg',
#  'worker (207).jpg',
#  'worker (196).jpg',
#  'worker (215).jpg']

# %%
def predict(image):
    image = preprocess_image(image.copy())
    #image, scale = resize_image(image)

    boxes, scores, labels = model.predict_on_batch(
    np.expand_dims(image, axis=0)
  )

    #boxes /= scale

    return boxes, scores, labels

# %%
THRES_SCORE = 0.35

def draw_detections(image, boxes, scores, labels):
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < THRES_SCORE:
            break

        color = label_color(label)

        b = box.astype(int)
        draw_box(image, b, color=color)

        caption = "{:.3f}".format(score)
        draw_caption(image, b, caption)

# %%
test_path = '/kaggle/input/test-helmet/test_images'

# %%
def show_detected_objects(image_name, boxes, scores, labels):
    img_path = test_path +'/'+ image_name
  
    image = read_image_bgr(img_path)
    draw = image.copy()
    draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

    draw_detections(draw, boxes, scores, labels)
    plt.figure(figsize=(15,10))
    plt.axis('off')
    plt.imshow(draw)
    plt.show()

# %%
pred_string=[]
for img in li:
    preds=''
    img_path = test_path+'/'+img
    image = read_image_bgr(img_path)
    boxes, scores, labels = predict(image)
    show_detected_objects(img, boxes, scores, labels)
    boxes=boxes[0]
    scores=scores[0]
    for idx in range(boxes.shape[0]):
        if scores[idx]>THRES_SCORE:
            box,score=boxes[idx],scores[idx]
            preds+="{:0.2f} {} {} {} {} ".format(score, int(box[0]), int(box[1]), int(box[2]-box[0]), int(box[3]-box[1]))
    pred_string.append(preds)
